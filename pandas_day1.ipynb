# %% [markdown]
# <a href="https://colab.research.google.com/github/raju451/Demo/blob/main/pandas_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("/content/Data Refresh Sample Data.xlsx")
df
# Out:
#          Ship Mode     Profit  Unit Price  Shipping Cost       Customer Name
# 0      Regular Air  -213.2500       38.94          35.00  Muhammed MacIntyre
# 1   Delivery Truck   457.8100      208.16          68.02        Barry French
# 2      Regular Air    46.7075        8.69           2.99        Barry French
# 3      Regular Air  1198.9710      195.99           3.99       Clay Rozendal
# 4      Regular Air    -4.7150        5.28           2.99       Claudia Miner
# 5      Regular Air   782.9100       39.89           3.04     Neola Schneider
# 6      Regular Air    93.8000       15.74           1.39    Allen Rosenblatt
# 7   Delivery Truck   440.7200      100.98          26.22     Sylvia Foulston
# 8      Regular Air  -481.0410      100.98          69.00     Sylvia Foulston
# 9      Regular Air   -11.6820       65.99           5.26         Jim Radford
# 10     Regular Air   313.5780      155.99           8.99         Jim Radford
# ...

# %%
#write file in excel
# df.to_excel("demo_data.xlsx")

# df.to_csv("import_data_csv.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ship Mode      22 non-null     object
#  1   Profit         22 non-null     float64
#  2   Unit Price     22 non-null     float64
#  3   Shipping Cost  22 non-null     float64
#  4   Customer Name  22 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 1008.0+ bytes

# %%
df.describe()
# Out:
#             Profit  Unit Price  Shipping Cost
# count    22.000000   22.000000      22.000000
# mean    191.239614  101.478636      17.818636
# std     901.638097  144.015500      23.762750
# min   -1766.010000    2.880000       0.500000
# 25%    -111.333000    6.132500       2.990000
# 50%      36.813750   40.425000       5.510000
# 75%     298.348500  115.980000      26.165000
# max    3424.220000  500.980000      74.350000

# %%
df.shape
# Out:
# (22, 5)

# %%
import pandas as pd
data = {
    "A": ["apple","Nan","mango", "carrot"],
    "B": ["red","nan","yellow", "green"]
}

df = pd.DataFrame(data)
# df["A"]=df["A"].replace("apple","fruit")
# df[["A", "B"]] = df[["A", "B"]].replace("apple", "fruit")
#df[["A", "B"]] = df[["A", "B"]].replace({"A": "apple", "B": "red"}, {"A": "fruit", "B": "citrus"})
df
# Out:
#         A       B
# 0   fruit  citrus
# 1     Nan     nan
# 2   mango  yellow
# 3  carrot   green
